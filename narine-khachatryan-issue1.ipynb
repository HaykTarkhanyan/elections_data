# %%
#pip install pandas pyarrow

# %%
#pip install fastparquet

# %%
import pandas as pd

# %%
df = pd.read_parquet("elections.parquet", engine="fastparquet")

# %%
df
# Out:
#                azganun        anun haeranun or_amis_tari    marz   hamaenq  \
# 0        Հարությունյան       Կարեն   Շաքարի   14/11/1997  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 1            Աղաջանյան      Կարինե   Ժորայի   14/08/1964  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 2        Հարությունյան  Հարություն   Շաքարի   29/10/1986  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 3           Ալեքսանյան      Համեստ   Արսենի   24/10/1954  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# 4        Հարությունյան       Շաքար   Արտաշի   01/01/1959  ԿՈՏԱՅՔ  ՆՈՐ ՀԱՃՆ
# ...                ...         ...      ...          ...     ...       ...
# 2577168     Շահվերդյան         Ալա   Աղասու   22/04/1987    ԼՈՌԻ   ՎԱՆԱՁՈՐ
# 2577169      Իսրաելյան      Կարինե   Վահանի   13/03/1960    ԼՈՌԻ     ԴԵԲԵԴ
# 2577170      Գրիգորյան      Անահիտ  Հունանի   12/05/1970    ԼՈՌԻ   ՎԱՆԱՁՈՐ
# 2577171       Սահակյան      Նարինե    Աշոտի   25/09/1978    ԼՈՌԻ   ՎԱՆԱՁՈՐ
# 2577172       Մկրտչյան      Գայանե  Գարուշի   24/04/1966    ԼՈՌԻ   ՎԱՆԱՁՈՐ
#
#         bnakavaer                      hasce  taracq texamas
# ...

# %%
df.columns
# Out:
# Index(['azganun', 'anun', 'haeranun', 'or_amis_tari', 'marz', 'hamaenq',
#        'bnakavaer', 'hasce', 'taracq', 'texamas'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577173 entries, 0 to 2577172
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   azganun       object
#  1   anun          object
#  2   haeranun      object
#  3   or_amis_tari  object
#  4   marz          object
#  5   hamaenq       object
#  6   bnakavaer     object
#  7   hasce         object
#  8   taracq        int64
#  9   texamas       object
# dtypes: int64(1), object(9)
# memory usage: 196.6+ MB

# %%
df.isna().sum()
# Out:
# azganun               0
# anun                  0
# haeranun            278
# or_amis_tari          0
# marz                 24
# hamaenq              24
# bnakavaer       2042152
# hasce               745
# taracq                0
# texamas               0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [azganun, anun, haeranun, or_amis_tari, marz, hamaenq, bnakavaer, hasce, taracq, texamas]
# Index: []

# %%
duplicate = df[df[["anun","azganun","haeranun","or_amis_tari"]].duplicated()]

# %%
duplicate
# Out:
#                azganun       anun  haeranun or_amis_tari       marz  \
# 45571          Միրոյան  Գյուլիզար   Սուտոյի   20/01/1939     ԿՈՏԱՅՔ
# 253259      Կարապետյան       Լալա   Ռազմիկի   25/03/1964  ԱՐԱԳԱԾՈՏՆ
# 539565       Խաչատրյան       Էրիկ    Արմենի   19/07/1998     ԵՐԵՎԱՆ
# 559156   Հարությունյան     Մարիամ    Արսենի   16/08/1992     ԵՐԵՎԱՆ
# 578070        Սարգսյան     Տիգրան     Մհերի   16/12/1981     ԱՐԱՐԱՏ
# ...                ...        ...       ...          ...        ...
# 2532130  Հարությունյան     Կարինե   Կոլյայի   01/01/1959       ԼՈՌԻ
# 2547003     Կարապետյան     Կարինե  Կարապետի   03/08/1960       ԼՈՌԻ
# 2547455     Մկրտումյան       Աննա   Սամվելի   20/09/1994       ԼՈՌԻ
# 2566916      Խաչատրյան      Դավիթ    Պավելի   07/01/1983       ԼՈՌԻ
# 2568410      Խաչատրյան       Աննա   Սամվելի   02/02/1988       ԼՈՌԻ
#
#              hamaenq bnakavaer                                 hasce  taracq  \
# ...

# %%
duplicate["or_amis_tari"].nunique()
# Out:
# 101

# %%
#so, there is no person with the same first name, last name, and date of birth
